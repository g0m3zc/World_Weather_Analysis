# %%
# Import dependancies

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from citipy import citipy

import time

# Import the API key.
from config import weather_api_key

from datetime import datetime

import requests

# %%
# Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size = 2000)
lat_lngs = zip(lats, lngs)
coordinates = list(lat_lngs)

# Get the nearest city using the citipy module.

cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 758

# %%
# Perform an API call with the OpenWeatherMap.
# Starting URL for Weather Map API call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port-gentil
# Processing Record 2 of Set 1 | saldanha
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | torbay
# Processing Record 5 of Set 1 | laguna
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | dattapur
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | qaanaaq
# Processing Record 10 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 1 | pangnirtung
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | saint-philippe
# Processing Record 15 of Set 1 | manicaragua
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | margate
# Processing Record 18 of Set 1 | abu kamal
# Processing Record 19 of Set 1 | sao filipe
# Processing Record 20 of Set 1 | methoni
# Processing Record 21 of Set 1 | guaranesia
# Processing Record 22 of Set 1 | victoria
# Processing Record 23 of Set 1 | iquique
# Processing Record 24 of Set 1 | witu
# Processing Record 25 of Set 1 | vila velha
# Processing Record 26 of Set 1 | massaguet
# Processing Record 27 of Set 1 | hobyo
# Processing Record 28 of Set 1 | marsh harbour
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | walvis bay
# Processing Record 32 of Set 1 | harwich
# Processing Record 33 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 34 of Set 1 | san andres
# Processing Record 35 of Set 1 | pisco
# Processing Record 36 of Set 1 | berlevag
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | burica
# City not found. Skipping...
# Processing Record 40 of Set 1 | jacareacanga
# Processing Record 41 of Set 1 | lagoa
# Processing Record 42 of Set 1 | san miguelito
# Processing Record 43 of Set 1 | viedma
# Processing Record 44 of Set 1 | george
# Processing Record 45 of Set 1 | kalengwa
# Processing Record 46 of Set 1 | bubaque
# Processing Record 47 of Set 1 | dingle
# Processing Record 48 of Set 1 | akropong
# Processing Record 49 of Set 1 | tikamgarh
# Processing Record 50 of Set 1 | cristalina
# Processing Record 1 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 2 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 2 | porto novo
# Processing Record 4 of Set 2 | kilindoni
# Processing Record 5 of Set 2 | kavaratti
# Processing Record 6 of Set 2 | riyadh
# Processing Record 7 of Set 2 | ribeira grande
# Processing Record 8 of Set 2 | irtyshskiy
# Processing Record 9 of Set 2 | jibuti
# Processing Record 10 of Set 2 | livingstonia
# Processing Record 11 of Set 2 | muisne
# Processing Record 12 of Set 2 | deh rawud
# City not found. Skipping...
# Processing Record 13 of Set 2 | arica
# Processing Record 14 of Set 2 | hithadhoo
# Processing Record 15 of Set 2 | longonjo
# Processing Record 16 of Set 2 | nantucket
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | arlit
# Processing Record 19 of Set 2 | faya
# Processing Record 20 of Set 2 | camacha
# Processing Record 21 of Set 2 | salinas
# Processing Record 22 of Set 2 | imbituba
# Processing Record 23 of Set 2 | quelimane
# Processing Record 24 of Set 2 | nowy targ
# Processing Record 25 of Set 2 | dharchula
# Processing Record 26 of Set 2 | carnarvon
# Processing Record 27 of Set 2 | bull savanna
# Processing Record 28 of Set 2 | misratah
# Processing Record 29 of Set 2 | quatre cocos
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | kostroma
# Processing Record 32 of Set 2 | lircay
# Processing Record 33 of Set 2 | matara
# Processing Record 34 of Set 2 | nanortalik
# Processing Record 35 of Set 2 | pyaozerskiy
# Processing Record 36 of Set 2 | georgetown
# Processing Record 37 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 2 | ibate
# Processing Record 39 of Set 2 | oranjemund
# Processing Record 40 of Set 2 | san cristobal
# Processing Record 41 of Set 2 | tasiilaq
# Processing Record 42 of Set 2 | san-pedro
# Processing Record 43 of Set 2 | kongwa
# Processing Record 44 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 2 | east london
# Processing Record 46 of Set 2 | bambous virieux
# Processing Record 47 of Set 2 | port alfred
# Processing Record 48 of Set 2 | novouzensk
# Processing Record 49 of Set 2 | grand gaube
# Processing Record 50 of Set 2 | jalu
# Processing Record 1 of Set 3 | carbonia
# Processing Record 2 of Set 3 | mar del plata
# Processing Record 3 of Set 3 | sechura
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | namibe
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | mangai
# Processing Record 8 of Set 3 | banda aceh
# Processing Record 9 of Set 3 | visnes
# Processing Record 10 of Set 3 | skibbereen
# Processing Record 11 of Set 3 | paranaiba
# Processing Record 12 of Set 3 | iqaluit
# Processing Record 13 of Set 3 | anloga
# Processing Record 14 of Set 3 | cayenne
# Processing Record 15 of Set 3 | ruwi
# Processing Record 16 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 17 of Set 3 | orel
# Processing Record 18 of Set 3 | madison
# Processing Record 19 of Set 3 | sibi
# Processing Record 20 of Set 3 | senanga
# Processing Record 21 of Set 3 | vardo
# Processing Record 22 of Set 3 | tombouctou
# Processing Record 23 of Set 3 | inta
# Processing Record 24 of Set 3 | inhambane
# Processing Record 25 of Set 3 | tchamba
# Processing Record 26 of Set 3 | save
# Processing Record 27 of Set 3 | sur
# Processing Record 28 of Set 3 | caravelas
# Processing Record 29 of Set 3 | acarau
# Processing Record 30 of Set 3 | almeirim
# Processing Record 31 of Set 3 | vengerovo
# Processing Record 32 of Set 3 | aksu
# Processing Record 33 of Set 3 | dragomiresti
# Processing Record 34 of Set 3 | longyearbyen
# Processing Record 35 of Set 3 | santa rosa
# Processing Record 36 of Set 3 | kumluca
# Processing Record 37 of Set 3 | puerto lopez
# Processing Record 38 of Set 3 | am timan
# Processing Record 39 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 40 of Set 3 | gat
# Processing Record 41 of Set 3 | general pico
# Processing Record 42 of Set 3 | geraldton
# Processing Record 43 of Set 3 | mahebourg
# Processing Record 44 of Set 3 | grand-lahou
# Processing Record 45 of Set 3 | padang
# Processing Record 46 of Set 3 | safaqis
# City not found. Skipping...
# Processing Record 47 of Set 3 | clyde river
# Processing Record 48 of Set 3 | biharamulo
# Processing Record 49 of Set 3 | korla
# Processing Record 50 of Set 3 | raudeberg
# Processing Record 1 of Set 4 | olafsvik
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | akureyri
# Processing Record 4 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 4 | san rafael
# Processing Record 6 of Set 4 | micheweni
# Processing Record 7 of Set 4 | paita
# Processing Record 8 of Set 4 | ambanja
# Processing Record 9 of Set 4 | ponta do sol
# Processing Record 10 of Set 4 | zaltan
# Processing Record 11 of Set 4 | moisakula
# Processing Record 12 of Set 4 | matadi
# Processing Record 13 of Set 4 | hukuntsi
# Processing Record 14 of Set 4 | bako
# Processing Record 15 of Set 4 | beyneu
# Processing Record 16 of Set 4 | chuy
# Processing Record 17 of Set 4 | saint-paul
# Processing Record 18 of Set 4 | general roca
# Processing Record 19 of Set 4 | scarborough
# Processing Record 20 of Set 4 | cidreira
# Processing Record 21 of Set 4 | lasa
# Processing Record 22 of Set 4 | segezha
# Processing Record 23 of Set 4 | storforshei
# Processing Record 24 of Set 4 | ancud
# Processing Record 25 of Set 4 | filadelfia
# Processing Record 26 of Set 4 | bengkulu
# Processing Record 27 of Set 4 | poddorye
# Processing Record 28 of Set 4 | moose factory
# Processing Record 29 of Set 4 | umm kaddadah
# Processing Record 30 of Set 4 | olinda
# Processing Record 31 of Set 4 | adrar
# Processing Record 32 of Set 4 | ponta delgada
# Processing Record 33 of Set 4 | san ramon
# Processing Record 34 of Set 4 | rocha
# Processing Record 35 of Set 4 | kasongo-lunda
# Processing Record 36 of Set 4 | asfi
# Processing Record 37 of Set 4 | saint george
# Processing Record 38 of Set 4 | togur
# Processing Record 39 of Set 4 | rawson
# Processing Record 40 of Set 4 | louis trichardt
# Processing Record 41 of Set 4 | atar
# Processing Record 42 of Set 4 | coihaique
# Processing Record 43 of Set 4 | kibungo
# Processing Record 44 of Set 4 | ludwigsfelde
# Processing Record 45 of Set 4 | kamenka
# Processing Record 46 of Set 4 | benghazi
# Processing Record 47 of Set 4 | los llanos de aridane
# Processing Record 48 of Set 4 | sombrio
# Processing Record 49 of Set 4 | kidal
# Processing Record 50 of Set 4 | bam
# Processing Record 1 of Set 5 | tenenkou
# Processing Record 2 of Set 5 | chastyye
# Processing Record 3 of Set 5 | harper
# Processing Record 4 of Set 5 | chissamba
# Processing Record 5 of Set 5 | taperoa
# Processing Record 6 of Set 5 | jumla
# Processing Record 7 of Set 5 | saurimo
# Processing Record 8 of Set 5 | tabou
# Processing Record 9 of Set 5 | bud
# Processing Record 10 of Set 5 | lebu
# Processing Record 11 of Set 5 | luderitz
# Processing Record 12 of Set 5 | halifax
# Processing Record 13 of Set 5 | omboue
# Processing Record 14 of Set 5 | sorland
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | kokologo
# Processing Record 17 of Set 5 | el rosario
# Processing Record 18 of Set 5 | paamiut
# Processing Record 19 of Set 5 | valparaiso
# Processing Record 20 of Set 5 | hattiesburg
# Processing Record 21 of Set 5 | castro
# Processing Record 22 of Set 5 | mogadishu
# Processing Record 23 of Set 5 | lyngdal
# Processing Record 24 of Set 5 | goderich
# Processing Record 25 of Set 5 | casablanca
# Processing Record 26 of Set 5 | havre-saint-pierre
# Processing Record 27 of Set 5 | kushmurun
# Processing Record 28 of Set 5 | huarmey
# Processing Record 29 of Set 5 | malindi
# Processing Record 30 of Set 5 | alnavar
# Processing Record 31 of Set 5 | mwinilunga
# Processing Record 32 of Set 5 | necochea
# Processing Record 33 of Set 5 | kinchil
# Processing Record 34 of Set 5 | liverpool
# Processing Record 35 of Set 5 | soyo
# Processing Record 36 of Set 5 | thompson
# Processing Record 37 of Set 5 | tabuk
# Processing Record 38 of Set 5 | yar-sale
# Processing Record 39 of Set 5 | dubrovnik
# Processing Record 40 of Set 5 | blagoyevo
# Processing Record 41 of Set 5 | jemnice
# Processing Record 42 of Set 5 | husavik
# Processing Record 43 of Set 5 | birjand
# Processing Record 44 of Set 5 | praia da vitoria
# Processing Record 45 of Set 5 | taminango
# Processing Record 46 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 5 | robertsport
# Processing Record 48 of Set 5 | puerto baquerizo moreno
# Processing Record 49 of Set 5 | richards bay
# Processing Record 50 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 6 | pavilosta
# Processing Record 2 of Set 6 | wilmington
# Processing Record 3 of Set 6 | tulum
# Processing Record 4 of Set 6 | anapolis
# Processing Record 5 of Set 6 | chulym
# Processing Record 6 of Set 6 | muros
# Processing Record 7 of Set 6 | tarhunah
# City not found. Skipping...
# Processing Record 8 of Set 6 | vila franca do campo
# Processing Record 9 of Set 6 | rundu
# Processing Record 10 of Set 6 | maragogi
# Processing Record 11 of Set 6 | skarnes
# Processing Record 12 of Set 6 | riachao das neves
# Processing Record 13 of Set 6 | coquimbo
# Processing Record 14 of Set 6 | vestbygda
# City not found. Skipping...
# Processing Record 15 of Set 6 | salalah
# Processing Record 16 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 6 | havoysund
# Processing Record 18 of Set 6 | rabo de peixe
# Processing Record 19 of Set 6 | venado tuerto
# Processing Record 20 of Set 6 | sao sebastiao
# Processing Record 21 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 6 | kalmunai
# Processing Record 23 of Set 6 | marquette
# Processing Record 24 of Set 6 | sirfa
# City not found. Skipping...
# Processing Record 25 of Set 6 | kudahuvadhoo
# Processing Record 26 of Set 6 | atbasar
# Processing Record 27 of Set 6 | la palma
# Processing Record 28 of Set 6 | higuey
# City not found. Skipping...
# Processing Record 29 of Set 6 | bosaso
# Processing Record 30 of Set 6 | serebryansk
# Processing Record 31 of Set 6 | bridgend
# Processing Record 32 of Set 6 | nuuk
# Processing Record 33 of Set 6 | willowmore
# Processing Record 34 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 35 of Set 6 | flic en flac
# Processing Record 36 of Set 6 | safwah
# City not found. Skipping...
# Processing Record 37 of Set 6 | kajaani
# Processing Record 38 of Set 6 | santa vitoria do palmar
# Processing Record 39 of Set 6 | narsaq
# Processing Record 40 of Set 6 | porto velho
# Processing Record 41 of Set 6 | vestmannaeyjar
# Processing Record 42 of Set 6 | rauma
# Processing Record 43 of Set 6 | san ignacio
# Processing Record 44 of Set 6 | pidhorodne
# Processing Record 45 of Set 6 | angoche
# Processing Record 46 of Set 6 | lobito
# Processing Record 47 of Set 6 | budogoshch
# Processing Record 48 of Set 6 | joensuu
# Processing Record 49 of Set 6 | mindelo
# Processing Record 50 of Set 6 | skopelos
# Processing Record 1 of Set 7 | batabano
# Processing Record 2 of Set 7 | verkhoshizhemye
# Processing Record 3 of Set 7 | pampierstad
# Processing Record 4 of Set 7 | bathsheba
# Processing Record 5 of Set 7 | mollendo
# Processing Record 6 of Set 7 | wajir
# Processing Record 7 of Set 7 | kruisfontein
# Processing Record 8 of Set 7 | touros
# Processing Record 9 of Set 7 | yokadouma
# Processing Record 10 of Set 7 | doha
# Processing Record 11 of Set 7 | hofn
# Processing Record 12 of Set 7 | tsumeb
# Processing Record 13 of Set 7 | sultanpur
# Processing Record 14 of Set 7 | kemijarvi
# Processing Record 15 of Set 7 | makinsk
# Processing Record 16 of Set 7 | rurrenabaque
# Processing Record 17 of Set 7 | miranda
# Processing Record 18 of Set 7 | witney
# Processing Record 19 of Set 7 | kroonstad
# Processing Record 20 of Set 7 | bakel
# Processing Record 21 of Set 7 | umm lajj
# Processing Record 22 of Set 7 | saint-pierre
# Processing Record 23 of Set 7 | tiznit
# Processing Record 24 of Set 7 | manjeshwar
# Processing Record 25 of Set 7 | novi iskar
# Processing Record 26 of Set 7 | brae
# Processing Record 27 of Set 7 | turayf
# Processing Record 28 of Set 7 | soloneshnoye
# Processing Record 29 of Set 7 | homa bay
# Processing Record 30 of Set 7 | obo
# Processing Record 31 of Set 7 | bimbo
# Processing Record 32 of Set 7 | sukhoy log
# Processing Record 33 of Set 7 | road town
# Processing Record 34 of Set 7 | vagur
# Processing Record 35 of Set 7 | aleksandrovka
# Processing Record 36 of Set 7 | otwock
# Processing Record 37 of Set 7 | primorsk
# Processing Record 38 of Set 7 | pangody
# Processing Record 39 of Set 7 | ostrovnoy
# Processing Record 40 of Set 7 | golfito
# Processing Record 41 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 42 of Set 7 | kutum
# Processing Record 43 of Set 7 | arraial do cabo
# Processing Record 44 of Set 7 | lichinga
# Processing Record 45 of Set 7 | barra do corda
# Processing Record 46 of Set 7 | eydhafushi
# Processing Record 47 of Set 7 | hudiksvall
# Processing Record 48 of Set 7 | cervo
# Processing Record 49 of Set 7 | sohbatpur
# Processing Record 50 of Set 7 | barranca
# Processing Record 1 of Set 8 | acajutiba
# Processing Record 2 of Set 8 | vestmanna
# Processing Record 3 of Set 8 | eatonton
# Processing Record 4 of Set 8 | san borja
# Processing Record 5 of Set 8 | raahe
# Processing Record 6 of Set 8 | san lawrenz
# Processing Record 7 of Set 8 | borsad
# Processing Record 8 of Set 8 | montepuez
# Processing Record 9 of Set 8 | grindavik
# Processing Record 10 of Set 8 | bajil
# Processing Record 11 of Set 8 | boa vista
# Processing Record 12 of Set 8 | gari
# Processing Record 13 of Set 8 | sanford
# Processing Record 14 of Set 8 | araouane
# Processing Record 15 of Set 8 | souillac
# Processing Record 16 of Set 8 | ngorongoro
# Processing Record 17 of Set 8 | sinnamary
# Processing Record 18 of Set 8 | uchaly
# Processing Record 19 of Set 8 | pereslavl-zalesskiy
# Processing Record 20 of Set 8 | nkhotakota
# Processing Record 21 of Set 8 | nanga eboko
# Processing Record 22 of Set 8 | erie
# Processing Record 23 of Set 8 | hambantota
# Processing Record 24 of Set 8 | hualmay
# Processing Record 25 of Set 8 | orumiyeh
# Processing Record 26 of Set 8 | nybro
# Processing Record 27 of Set 8 | asosa
# Processing Record 28 of Set 8 | venice
# Processing Record 29 of Set 8 | nchelenge
# Processing Record 30 of Set 8 | rolim de moura
# City not found. Skipping...
# Processing Record 31 of Set 8 | shache
# Processing Record 32 of Set 8 | tigre
# Processing Record 33 of Set 8 | akdagmadeni
# Processing Record 34 of Set 8 | lagos
# Processing Record 35 of Set 8 | ovada
# Processing Record 36 of Set 8 | damara
# Processing Record 37 of Set 8 | vyazma
# Processing Record 38 of Set 8 | maridi
# Processing Record 39 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 8 | strezhevoy
# Processing Record 41 of Set 8 | mandera
# Processing Record 42 of Set 8 | theodoriana
# Processing Record 43 of Set 8 | hilton head island
# Processing Record 44 of Set 8 | luanda
# Processing Record 45 of Set 8 | rio gallegos
# Processing Record 46 of Set 8 | cannington
# Processing Record 47 of Set 8 | djambala
# Processing Record 48 of Set 8 | teguise
# Processing Record 49 of Set 8 | littleton
# Processing Record 50 of Set 8 | gamba
# Processing Record 1 of Set 9 | kuznetsk
# Processing Record 2 of Set 9 | bobonong
# City not found. Skipping...
# Processing Record 3 of Set 9 | singarayakonda
# Processing Record 4 of Set 9 | chicama
# Processing Record 5 of Set 9 | lefka
# Processing Record 6 of Set 9 | miram shah
# Processing Record 7 of Set 9 | izhma
# Processing Record 8 of Set 9 | ambilobe
# Processing Record 9 of Set 9 | talcahuano
# Processing Record 10 of Set 9 | colares
# Processing Record 11 of Set 9 | grand baie
# Processing Record 12 of Set 9 | nisia floresta
# Processing Record 13 of Set 9 | taoudenni
# Processing Record 14 of Set 9 | saint-francois
# Processing Record 15 of Set 9 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 9 | capao da canoa
# Processing Record 17 of Set 9 | baturite
# Processing Record 18 of Set 9 | saint-martin-boulogne
# Processing Record 19 of Set 9 | pailon
# Processing Record 20 of Set 9 | assela
# City not found. Skipping...
# Processing Record 21 of Set 9 | bilma
# Processing Record 22 of Set 9 | jaffna
# Processing Record 23 of Set 9 | mtsamboro
# Processing Record 24 of Set 9 | eyemouth
# Processing Record 25 of Set 9 | maldonado
# Processing Record 26 of Set 9 | hamilton
# Processing Record 27 of Set 9 | makat
# Processing Record 28 of Set 9 | new scone
# Processing Record 29 of Set 9 | huicungo
# Processing Record 30 of Set 9 | ruthin
# Processing Record 31 of Set 9 | cap malheureux
# Processing Record 32 of Set 9 | sao joao da barra
# Processing Record 33 of Set 9 | saint-georges
# Processing Record 34 of Set 9 | bhandara
# Processing Record 35 of Set 9 | karkaralinsk
# City not found. Skipping...
# Processing Record 36 of Set 9 | kedrovyy
# Processing Record 37 of Set 9 | beberibe
# Processing Record 38 of Set 9 | koson
# Processing Record 39 of Set 9 | dvurechensk
# Processing Record 40 of Set 9 | saint-augustin
# Processing Record 41 of Set 9 | dhidhdhoo
# Processing Record 42 of Set 9 | mandeville
# Processing Record 43 of Set 9 | thinadhoo
# Processing Record 44 of Set 9 | kurlovo
# Processing Record 45 of Set 9 | ust-ishim
# Processing Record 46 of Set 9 | gryazi
# Processing Record 47 of Set 9 | sao paulo de olivenca
# Processing Record 48 of Set 9 | sharjah
# Processing Record 49 of Set 9 | cerrito
# Processing Record 50 of Set 9 | jutai
# Processing Record 1 of Set 10 | chapais
# Processing Record 2 of Set 10 | mamlyutka
# Processing Record 3 of Set 10 | lentini
# Processing Record 4 of Set 10 | bahia honda
# Processing Record 5 of Set 10 | saint-leu
# Processing Record 6 of Set 10 | gubkin
# Processing Record 7 of Set 10 | penzance
# Processing Record 8 of Set 10 | barcelos
# Processing Record 9 of Set 10 | cockburn town
# Processing Record 10 of Set 10 | mehamn
# Processing Record 11 of Set 10 | wolmaranstad
# City not found. Skipping...
# Processing Record 12 of Set 10 | esna
# Processing Record 13 of Set 10 | mangrol
# Processing Record 14 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 15 of Set 10 | ritchie
# Processing Record 16 of Set 10 | kirkwall
# Processing Record 17 of Set 10 | yarke pole
# Processing Record 18 of Set 10 | tabligbo
# Processing Record 19 of Set 10 | akdepe
# Processing Record 20 of Set 10 | shelburne
# Processing Record 21 of Set 10 | sao jose da coroa grande
# Processing Record 22 of Set 10 | lexington
# Processing Record 23 of Set 10 | norrtalje
# Processing Record 24 of Set 10 | igrim
# Processing Record 25 of Set 10 | rebrikha
# Processing Record 26 of Set 10 | alcantara
# Processing Record 27 of Set 10 | korem
# Processing Record 28 of Set 10 | bandarbeyla
# Processing Record 29 of Set 10 | najran
# Processing Record 30 of Set 10 | leh
# Processing Record 31 of Set 10 | almaty
# Processing Record 32 of Set 10 | veshenskaya
# Processing Record 33 of Set 10 | nikel
# Processing Record 34 of Set 10 | bobo dioulasso
# Processing Record 35 of Set 10 | giyani
# Processing Record 36 of Set 10 | pavlohrad
# Processing Record 37 of Set 10 | deep river
# Processing Record 38 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 39 of Set 10 | matiguas
# Processing Record 40 of Set 10 | puerto asis
# Processing Record 41 of Set 10 | cabedelo
# Processing Record 42 of Set 10 | maniitsoq
# Processing Record 43 of Set 10 | albany
# Processing Record 44 of Set 10 | nouakchott
# Processing Record 45 of Set 10 | aripuana
# Processing Record 46 of Set 10 | dori
# Processing Record 47 of Set 10 | kristianstad
# Processing Record 48 of Set 10 | pombia
# Processing Record 49 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 50 of Set 10 | maiduguri
# Processing Record 1 of Set 11 | henties bay
# Processing Record 2 of Set 11 | kabalo
# Processing Record 3 of Set 11 | the valley
# Processing Record 4 of Set 11 | caceres
# Processing Record 5 of Set 11 | itarema
# Processing Record 6 of Set 11 | thanesar
# Processing Record 7 of Set 11 | alvdal
# Processing Record 8 of Set 11 | puerres
# Processing Record 9 of Set 11 | kolyvan
# Processing Record 10 of Set 11 | havelock
# Processing Record 11 of Set 11 | placido de castro
# Processing Record 12 of Set 11 | buy
# Processing Record 13 of Set 11 | porto seguro
# Processing Record 14 of Set 11 | areka
# Processing Record 15 of Set 11 | belmonte
# Processing Record 16 of Set 11 | cocobeach
# Processing Record 17 of Set 11 | olecko
# Processing Record 18 of Set 11 | loum
# Processing Record 19 of Set 11 | chabahar
# Processing Record 20 of Set 11 | gondal
# Processing Record 21 of Set 11 | sao felix do xingu
# Processing Record 22 of Set 11 | balkanabat
# Processing Record 23 of Set 11 | rawah
# Processing Record 24 of Set 11 | formosa
# Processing Record 25 of Set 11 | nyrob
# Processing Record 26 of Set 11 | ferrol
# Processing Record 27 of Set 11 | tabas
# Processing Record 28 of Set 11 | khor
# Processing Record 29 of Set 11 | santander
# Processing Record 30 of Set 11 | bonita springs
# Processing Record 31 of Set 11 | ocho rios
# Processing Record 32 of Set 11 | segou
# Processing Record 33 of Set 11 | athy
# Processing Record 34 of Set 11 | linares
# Processing Record 35 of Set 11 | belle glade
# Processing Record 36 of Set 11 | agadez
# Processing Record 37 of Set 11 | axim
# Processing Record 38 of Set 11 | porbandar
# Processing Record 39 of Set 11 | annau
# Processing Record 40 of Set 11 | colquechaca
# Processing Record 41 of Set 11 | pendencias
# Processing Record 42 of Set 11 | altay
# Processing Record 43 of Set 11 | nargana
# Processing Record 44 of Set 11 | kollumerland
# City not found. Skipping...
# Processing Record 45 of Set 11 | iquitos
# Processing Record 46 of Set 11 | borgarnes
# Processing Record 47 of Set 11 | garowe
# Processing Record 48 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 49 of Set 11 | terre haute
# Processing Record 50 of Set 11 | chipiona
# Processing Record 1 of Set 12 | sokoni
# Processing Record 2 of Set 12 | la asuncion
# Processing Record 3 of Set 12 | mitsamiouli
# Processing Record 4 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 5 of Set 12 | acopiara
# Processing Record 6 of Set 12 | bukama
# Processing Record 7 of Set 12 | boa viagem
# Processing Record 8 of Set 12 | marawi
# Processing Record 9 of Set 12 | ondangwa
# Processing Record 10 of Set 12 | nokaneng
# Processing Record 11 of Set 12 | tete
# Processing Record 12 of Set 12 | komsomolets
# Processing Record 13 of Set 12 | talnakh
# Processing Record 14 of Set 12 | buraydah
# Processing Record 15 of Set 12 | yining
# Processing Record 16 of Set 12 | sebring
# Processing Record 17 of Set 12 | vetluga
# Processing Record 18 of Set 12 | zabalj
# Processing Record 19 of Set 12 | camara de lobos
# Processing Record 20 of Set 12 | les cayes
# Processing Record 21 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 22 of Set 12 | atkarsk
# Processing Record 23 of Set 12 | marsabit
# Processing Record 24 of Set 12 | siyabuswa
# Processing Record 25 of Set 12 | plettenberg bay
# Processing Record 26 of Set 12 | ryazan
# Processing Record 27 of Set 12 | yeletskiy
# City not found. Skipping...
# Processing Record 28 of Set 12 | westport
# Processing Record 29 of Set 12 | mao
# Processing Record 30 of Set 12 | borba
# Processing Record 31 of Set 12 | morondava
# Processing Record 32 of Set 12 | mahuta
# Processing Record 33 of Set 12 | zeerust
# Processing Record 34 of Set 12 | romanovo
# Processing Record 35 of Set 12 | mumford
# Processing Record 36 of Set 12 | minas
# Processing Record 37 of Set 12 | mastic beach
# Processing Record 38 of Set 12 | la romana
# Processing Record 39 of Set 12 | tessalit
# Processing Record 40 of Set 12 | sept-iles
# Processing Record 41 of Set 12 | camapua
# Processing Record 42 of Set 12 | bundibugyo
# Processing Record 43 of Set 12 | jacqueville
# Processing Record 44 of Set 12 | taltal
# Processing Record 45 of Set 12 | japura
# Processing Record 46 of Set 12 | sonegaon
# Processing Record 47 of Set 12 | floro
# Processing Record 48 of Set 12 | elizabeth city
# Processing Record 49 of Set 12 | sant julia de loria
# Processing Record 50 of Set 12 | talas
# Processing Record 1 of Set 13 | fatsa
# Processing Record 2 of Set 13 | orizona
# Processing Record 3 of Set 13 | mtambile
# Processing Record 4 of Set 13 | sembe
# Processing Record 5 of Set 13 | mazamari
# Processing Record 6 of Set 13 | oussouye
# Processing Record 7 of Set 13 | koungou
# Processing Record 8 of Set 13 | langen
# Processing Record 9 of Set 13 | berbera
# Processing Record 10 of Set 13 | svolvaer
# Processing Record 11 of Set 13 | krasnoselkup
# Processing Record 12 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 13 | abu dhabi
# Processing Record 14 of Set 13 | janauba
# Processing Record 15 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 16 of Set 13 | rio grande
# Processing Record 17 of Set 13 | chuchkovo
# Processing Record 18 of Set 13 | garmsar
# Processing Record 19 of Set 13 | brigantine
# Processing Record 20 of Set 13 | luba
# Processing Record 21 of Set 13 | iralaya
# Processing Record 22 of Set 13 | vigrestad
# Processing Record 23 of Set 13 | colquiri
# Processing Record 24 of Set 13 | cuiaba
# Processing Record 25 of Set 13 | kangaatsiaq
# Processing Record 26 of Set 13 | usinsk
# Processing Record 27 of Set 13 | winneba
# Processing Record 28 of Set 13 | novyy urengoy
# Processing Record 29 of Set 13 | cueto
# Processing Record 30 of Set 13 | pithoragarh
# Processing Record 31 of Set 13 | santa fe
# Processing Record 32 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 13 | laishevo
# Processing Record 34 of Set 13 | port-cartier
# Processing Record 35 of Set 13 | ous
# Processing Record 36 of Set 13 | mananjary
# Processing Record 37 of Set 13 | inirida
# Processing Record 38 of Set 13 | tobermory
# Processing Record 39 of Set 13 | mahon
# Processing Record 40 of Set 13 | pontassieve
# Processing Record 41 of Set 13 | aswan
# Processing Record 42 of Set 13 | nicoya
# Processing Record 43 of Set 13 | amot
# Processing Record 44 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 45 of Set 13 | leshukonskoye
# Processing Record 46 of Set 13 | belyy yar
# Processing Record 47 of Set 13 | tutoia
# Processing Record 48 of Set 13 | pitea
# Processing Record 49 of Set 13 | rondonopolis
# Processing Record 50 of Set 13 | odweyne
# Processing Record 1 of Set 14 | jawhar
# Processing Record 2 of Set 14 | ardistan
# City not found. Skipping...
# Processing Record 3 of Set 14 | rockland
# Processing Record 4 of Set 14 | kirovsk
# Processing Record 5 of Set 14 | timiryazevskiy
# Processing Record 6 of Set 14 | bonavista
# Processing Record 7 of Set 14 | cave spring
# Processing Record 8 of Set 14 | kosh-agach
# Processing Record 9 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 14 | bikaner
# Processing Record 11 of Set 14 | andijon
# Processing Record 12 of Set 14 | volnovakha
# Processing Record 13 of Set 14 | songea
# Processing Record 14 of Set 14 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 14 | clarence town
# Processing Record 16 of Set 14 | morrinhos
# Processing Record 17 of Set 14 | villazon
# Processing Record 18 of Set 14 | grahamstown
# Processing Record 19 of Set 14 | chongwe
# Processing Record 20 of Set 14 | goundi
# Processing Record 21 of Set 14 | maracaibo
# Processing Record 22 of Set 14 | gravdal
# Processing Record 23 of Set 14 | birao
# Processing Record 24 of Set 14 | puerto quijarro
# Processing Record 25 of Set 14 | jeronimo monteiro
# Processing Record 26 of Set 14 | zelenoborsk
# Processing Record 27 of Set 14 | prestea
# Processing Record 28 of Set 14 | mizan teferi
# Processing Record 29 of Set 14 | stilfontein
# Processing Record 30 of Set 14 | mhlume
# Processing Record 31 of Set 14 | bolotnoye
# Processing Record 32 of Set 14 | behbahan
# Processing Record 33 of Set 14 | berea
# Processing Record 34 of Set 14 | malinovoye ozero
# Processing Record 35 of Set 14 | kota
# Processing Record 36 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 37 of Set 14 | knysna
# Processing Record 38 of Set 14 | pokaran
# Processing Record 39 of Set 14 | chimbote
# Processing Record 40 of Set 14 | marystown
# Processing Record 41 of Set 14 | ambam
# Processing Record 42 of Set 14 | el alto
# Processing Record 43 of Set 14 | kisangani
# Processing Record 44 of Set 14 | matagami
# Processing Record 45 of Set 14 | severnyy
# Processing Record 46 of Set 14 | isoka
# Processing Record 47 of Set 14 | ebolowa
# Processing Record 48 of Set 14 | tucuma
# Processing Record 49 of Set 14 | qaqortoq
# Processing Record 50 of Set 14 | tulsipur
# Processing Record 1 of Set 15 | urumqi
# Processing Record 2 of Set 15 | yuzhnyy
# Processing Record 3 of Set 15 | ballina
# Processing Record 4 of Set 15 | waterboro
# Processing Record 5 of Set 15 | likasi
# Processing Record 6 of Set 15 | obera
# Processing Record 7 of Set 15 | skelleftea
# Processing Record 8 of Set 15 | bocas del toro
# Processing Record 9 of Set 15 | olavarria
# Processing Record 10 of Set 15 | kjollefjord
# Processing Record 11 of Set 15 | maceio
# Processing Record 12 of Set 15 | dogbo
# Processing Record 13 of Set 15 | matay
# Processing Record 14 of Set 15 | mutsamudu
# City not found. Skipping...
# Processing Record 15 of Set 15 | ramhormoz
# Processing Record 16 of Set 15 | saint anthony
# Processing Record 17 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 15 | fecamp
# Processing Record 19 of Set 15 | manjacaze
# Processing Record 20 of Set 15 | jaguaribe
# Processing Record 21 of Set 15 | chyhyryn
# Processing Record 22 of Set 15 | takoradi
# Processing Record 23 of Set 15 | urdzhar
# City not found. Skipping...
# Processing Record 24 of Set 15 | kreuztal
# Processing Record 25 of Set 15 | kot isa khan
# Processing Record 26 of Set 15 | krutikha
# Processing Record 27 of Set 15 | dirba
# Processing Record 28 of Set 15 | white oak
# Processing Record 29 of Set 15 | tiruvottiyur
# City not found. Skipping...
# Processing Record 30 of Set 15 | sumkino
# Processing Record 31 of Set 15 | oskemen
# Processing Record 32 of Set 15 | florianopolis
# Processing Record 33 of Set 15 | albanel
# Processing Record 34 of Set 15 | sungurlu
# Processing Record 35 of Set 15 | kosonsoy
# Processing Record 36 of Set 15 | conakry
# Processing Record 37 of Set 15 | kozhva
# Processing Record 38 of Set 15 | bonthe
# Processing Record 39 of Set 15 | kamina
# Processing Record 40 of Set 15 | conde
# Processing Record 41 of Set 15 | ormara
# Processing Record 42 of Set 15 | conceicao do araguaia
# Processing Record 43 of Set 15 | sabha
# Processing Record 44 of Set 15 | skalistyy
# City not found. Skipping...
# Processing Record 45 of Set 15 | dunayivtsi
# City not found. Skipping...
# Processing Record 46 of Set 15 | medak
# Processing Record 47 of Set 15 | mitu
# Processing Record 48 of Set 15 | andenes
# Processing Record 49 of Set 15 | caala
# Processing Record 50 of Set 15 | tallahassee
# Processing Record 1 of Set 16 | sisimiut
# Processing Record 2 of Set 16 | tibiri
# Processing Record 3 of Set 16 | southampton
# Processing Record 4 of Set 16 | diamantina
# Processing Record 5 of Set 16 | kargat
# Processing Record 6 of Set 16 | gurupa
# Processing Record 7 of Set 16 | ovre ardal
# Processing Record 8 of Set 16 | sayat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 703

# %%
# Add the data to a new DataFrame.

# Before exporting your new DataFrame as a CSV file, take a moment to confirm 
# that it looks similar to the screenshot.

city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Port-Gentil      GA  -0.7193    8.7815     73.36        94          75
# 1     Saldanha      ZA -33.0117   17.9442     51.85        83         100
# 2       Torbay      CA  47.6666  -52.7314     58.26        95         100
# 3       Laguna      US  38.4210 -121.4238     73.44        62           0
# 4   Bredasdorp      ZA -34.5322   20.0403     52.00        94         100
#
#    Wind Speed Current Description
# 0        5.75       broken clouds
# 1        5.88     overcast clouds
# 2        6.91     overcast clouds
# 3        8.05           clear sky
# 4        8.12          light rain

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv 
# in the Weather_Database folder.


# Create the output file in CSV
output_data_file = "WeatherPy_Database.csv"

# Export the city data into a csv
city_data_df.to_csv(output_data_file, index_label = "City_ID")
